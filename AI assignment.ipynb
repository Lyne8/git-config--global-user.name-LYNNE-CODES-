# %%
import pandas as pd 
df = pd.read_csv("C:/Users/HP/Downloads/archive (2)/marriage.csv")
df.tail(35)
# Out:
#         id  gender height   religion  age_of_marriage
# 2532  2533  female   5'0"      Hindu             31.0
# 2533  2534  female   5'3"      Hindu             32.0
# 2534  2535  female  4'11"      Hindu             27.0
# 2535  2536  female   5'3"       Sikh             30.0
# 2536  2537    male   5'9"      Hindu             31.0
# 2537  2538  female   5'2"      Hindu             27.0
# 2538  2539    male   6'0"       Sikh             30.0
# 2539  2540    male   5'8"        NaN             28.0
# 2540  2541  female   5'6"        NaN             25.0
# 2541  2542  female   5'8"        NaN             35.0
# 2542  2543    male   6'4"        NaN             34.0
# 2543  2544  female   5'6"      Hindu             26.0
# 2544  2545  female   5'3"      Hindu             31.0
# 2545  2546  female    NaN        NaN             25.0
# 2546  2547    male   5'2"      Hindu             31.0
# 2547  2548    male   5'4"      Hindu             32.0
# ...

# %%
female_df= df[df['gender'] =='female'][:25]

# %%
female_df
# Out:
#     id  gender height   religion  age_of_marriage
# 0    1  female   5'4"        NaN             21.0
# 3    4  female   5'0"      Hindu             30.0
# 6    7  female   5'2"      Hindu             28.0
# 8    9  female   5'5"       Jain             35.0
# 9   10  female   5'1"      Hindu             32.0
# 10  11  female   5'3"        NaN             29.0
# 14  15  female   5'1"      Hindu             30.0
# 15  16  female   5'2"  Christian             31.0
# 16  17  female   5'6"        NaN             35.0
# 17  18  female   5'3"      Hindu             28.0
# 18  19  female   5'3"      Hindu             28.0
# 20  21  female   5'3"  Christian             31.0
# 21  22  female   4'5"        NaN             20.0
# 24  25  female   5'3"      Hindu             29.0
# 25  26  female   5'4"      Hindu             28.0

# %%
df.tail(15)

# %%
height_list= female_df['gender']
female_df['height'].tolist()
# Out:
# ['5\'4"',
#  '5\'0"',
#  '5\'2"',
#  '5\'5"',
#  '5\'1"',
#  '5\'3"',
#  '5\'1"',
#  '5\'2"',
#  '5\'6"',
#  '5\'3"',
#  '5\'3"',
#  '5\'3"',
#  '4\'5"',
#  '5\'3"',
#  '5\'4"',
#  '5\'2"',
#  '5\'3"',
#  '5\'8"',
#  '5\'6"',
#  '5\'3"',
#  '4\'5"',
#  '5\'6"',
#  '5\'0"',
#  '5\'1"',
#  '6\'5"']

# %%
height_list= female_df['gender']
female_df['age_of_marriage'].tolist()
# Out:
# [21.0,
#  30.0,
#  28.0,
#  35.0,
#  32.0,
#  29.0,
#  30.0,
#  31.0,
#  35.0,
#  28.0,
#  28.0,
#  31.0,
#  20.0,
#  29.0,
#  28.0,
#  29.0,
#  29.0,
#  26.0,
#  26.0,
#  30.0,
#  31.0,
#  27.0,
#  30.0,
#  35.0,
#  29.0]

# %%
def line_of_best_fit(xs,ys):

    slope =(((mean(xs)*(mean(ys)-mean(xs*ys)/(mean(xs)*(mean(ys)-mean(xs*xs)))))))

    y_intercept= mean(ys)-slope*mean(xs)
    return slope,y_intercept

# %%
import numpy as np

# %%
xs = np.array((height_list),dtype = np.int32)
xs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 xs = np.array((height_list),dtype = np.int32)
#       2 xs
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:917, in Series.__array__(self, dtype)
#     870 """
#     871 Return the values as a NumPy array.
#     872
#    (...)
#     914       dtype='datetime64[ns]')
#     915 """
#     916 values = self._values
# --> 917 arr = np.asarray(values, dtype=dtype)
#     918 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     919     arr = arr.view()
#
# ValueError: invalid literal for int() with base 10: 'female'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 xs
#
# NameError: name 'xs' is not defined
